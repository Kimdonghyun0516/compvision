# %% [markdown]
# ## Homework3

# %%
import cv2
import numpy as np

img = cv2.imread('sIMG_8253.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 50, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]
    
    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)
    
    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)
    

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

#cont_img = closing.copy()
#contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)    

cv2.imshow('detected circles',img_color)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
cv2.imshow("Original", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread('sIMG_8254.jpg',1)
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color1 = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]
    
    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)
    
    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)

gray_blur1 = cv2.GaussianBlur(gray1, (15, 15), 0)
thresh1 = cv2.adaptiveThreshold(gray_blur1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img1 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow('detected circles',img_color1)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh1)
# cv2.imshow("Contours", img1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread('sIMG_8254.jpg',1)
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img_gray1 = cv2.medianBlur(img_gray1,5)
img_color1 = cv2.cvtColor(img_gray1,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray1,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]
    
    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)
    
    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)

gray_blur1 = cv2.GaussianBlur(gray1, (15, 15), 0)
thresh1 = cv2.adaptiveThreshold(gray_blur1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img1 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)
    
cv2.imshow('detected circles',img_color1)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh1)
cv2.imshow("Contours", img1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('sIMG_8255.jpg',1)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

gray_blur2 = cv2.GaussianBlur(gray2, (15, 15), 0)
thresh2 = cv2.adaptiveThreshold(gray_blur2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh2, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img2 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh2)
cv2.imshow("Contours", img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img3 = cv2.imread('sIMG_8256.jpg',1)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

gray_blur3 = cv2.GaussianBlur(gray3, (15, 15), 0)
thresh3 = cv2.adaptiveThreshold(gray_blur3, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh3, cv2.MORPH_CLOSE, kernel, iterations=4)


cont_img3 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img3, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh3)
cv2.imshow("Contours", img3)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sIMG_8253.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kerne = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img = closing.copy()
contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)
    
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
cv2.imshow("contours", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = cv2.imread('sIMG_8254.jpg',1)
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

gray_blur1 = cv2.GaussianBlur(gray1, (15, 15), 0)
thresh1 = cv2.adaptiveThreshold(gray_blur1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img1 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img1, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh1)
cv2.imshow("Contours", img1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = cv2.imread('sIMG_8255.jpg',1)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

gray_blur2 = cv2.GaussianBlur(gray2, (15, 15), 0)
thresh2 = cv2.adaptiveThreshold(gray_blur2, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh2, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img2 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh2)
cv2.imshow("Contours", img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img3 = cv2.imread('sIMG_8256.jpg',1)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

gray_blur3 = cv2.GaussianBlur(gray3, (15, 15), 0)
thresh3 = cv2.adaptiveThreshold(gray_blur3, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh3, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img3 = closing.copy()
contours, hierarchy = cv2.findContours(cont_img3, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue
        
    if len(cnt) < 5:
        continue
        
    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img1, ellipse, (0, 255, 0), 2)

cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshol", thresh)
cv2.imshow("Contours", img3)

cv2.waitKey(0)
cv2.destroyAllWindows()
